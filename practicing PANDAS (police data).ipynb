# %%
import pandas as pd

# %%
df = pd.read_csv("police.csv") #loading csv file

# %%
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'county_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %%
data=pd.DataFrame(df[[ 'driver_gender','driver_age', 'driver_race','violation', 'search_conducted', 'search_type', 'stop_outcome','is_arrested',  'drugs_related_stop']])
# removing unwanted columns

# %%
data
# Out:
#       driver_gender  driver_age driver_race         violation  \
# 0                 M        20.0       White          Speeding
# 1                 M        40.0       White          Speeding
# 2                 M        33.0       White          Speeding
# 3                 M        19.0       White             Other
# 4                 F        21.0       White          Speeding
# ...             ...         ...         ...               ...
# 91736             M        29.0       White          Speeding
# 91737             F        33.0       White         Equipment
# 91738             M        23.0       White  Moving violation
# 91739             M        22.0       White          Speeding
# 91740             M        56.0    Hispanic          Speeding
#
#        search_conducted search_type   stop_outcome is_arrested  \
# 0                 False         NaN       Citation       False
# 1                 False         NaN       Citation       False
# ...

# %%
data.shape
# Out:
# (91741, 9)

# %%
data.describe()
# Out:
#          driver_age
# count  86120.000000
# mean      34.011333
# std       12.738564
# min       15.000000
# 25%       23.000000
# 50%       31.000000
# 75%       43.000000
# max       99.000000

# %%
data.isnull().sum()    # finding total null values in each column
# Out:
# driver_gender          5335
# driver_age             5621
# driver_race            5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# drugs_related_stop        0
# dtype: int64

# %%
data.driver_age.mode()
# mode gives most repeted values
# this also specify age group who have commited most crimes
# Out:
# 0    22.0
# dtype: float64

# %%
data.driver_race.value_counts()
#diversity of people of different races stopped.
# Out:
# White       62158
# Black       12244
# Hispanic     9507
# Asian        2259
# Other         240
# Name: driver_race, dtype: int64

# %%
data.search_conducted.sum()
# Out:
# 3196

# %%
data.search_type.value_counts()   # causes for vehicle pullover
# Out:
# Incident to Arrest                                          1219
# Probable Cause                                               891
# Inventory                                                    220
# Reasonable Suspicion                                         197
# Protective Frisk                                             161
# Incident to Arrest,Inventory                                 129
# Incident to Arrest,Probable Cause                            106
# Probable Cause,Reasonable Suspicion                           75
# Incident to Arrest,Inventory,Probable Cause                   34
# Incident to Arrest,Protective Frisk                           33
# Probable Cause,Protective Frisk                               33
# Inventory,Probable Cause                                      22
# Incident to Arrest,Reasonable Suspicion                       13
# Incident to Arrest,Inventory,Protective Frisk                 11
# ...

# %%
data.is_arrested.sum()  # people arrested by police during pullover
# Out:
# 2929

# %%
data.stop_outcome.value_counts()  #other outcomes of pullover
# Out:
# Citation            77006
# Warning              5294
# Arrest Driver        2571
# N/D                   590
# No Action             589
# Arrest Passenger      358
# Name: stop_outcome, dtype: int64

# %%
data.violation.value_counts()
# Out:
# Speeding               48463
# Moving violation       16224
# Equipment              11020
# Other                   4317
# Registration/plates     3432
# Seat belt               2952
# Name: violation, dtype: int64

# %%
data.drugs_related_stop.sum()
# Out:
# 815

# %%
data.driver_age.min()  # finding lowest age of drivers
# Out:
# 15.0

# %%
data[data.driver_age==data.driver_age.min()]  
#number of times underage drivers caught
# Out:
#       driver_gender  driver_age driver_race         violation  \
# 10500             M        15.0       Black  Moving violation
# 17771             M        15.0       White          Speeding
# 18357             F        15.0       White  Moving violation
# 25294             M        15.0    Hispanic  Moving violation
# 45988             F        15.0       White  Moving violation
#
#        search_conducted         search_type   stop_outcome is_arrested  \
# 10500             False                 NaN  Arrest Driver        True
# 17771             False                 NaN       Citation       False
# 18357             False                 NaN  Arrest Driver        True
# 25294              True  Incident to Arrest  Arrest Driver        True
# 45988             False                 NaN       Citation       False
#
#        drugs_related_stop
# 10500               False
# 17771               False
# 18357               False
# 25294               False
# 45988               False

# %%
data[(data.drugs_related_stop) & (data.driver_age >= data.driver_age.min())]
# Out:
#       driver_gender  driver_age driver_race         violation  \
# 40                M        17.0       White         Equipment
# 41                M        17.0       White         Equipment
# 118               M        49.0       White  Moving violation
# 139               M        25.0       Black         Equipment
# 219               M        19.0       White             Other
# ...             ...         ...         ...               ...
# 91194             M        24.0    Hispanic  Moving violation
# 91253             M        22.0    Hispanic          Speeding
# 91284             M        39.0       White  Moving violation
# 91672             F        19.0       White             Other
# 91700             F        28.0    Hispanic          Speeding
#
#        search_conducted                          search_type  \
# 40                 True                       Probable Cause
# 41                 True                       Probable Cause
# ...

# %%
data.driver_age.mean()
# Out:
# 34.011333023687875
